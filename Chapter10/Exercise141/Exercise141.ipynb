# %%
import pandas as pd
housing_df = pd.read_csv('HousingData.csv')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = housing_df['RM']
y = housing_df['MEDV']
plt.scatter(x, y)
plt.show()
