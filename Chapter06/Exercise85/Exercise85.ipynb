# %%
import dataclasses
@dataclasses.dataclass
class Point:
    x: int
    y: int

# %%
p = Point(x=10, y=20)
print(p)
# Out:
# Point(x=10, y=20)

# %%
p2 = Point(x=10, y=20)
p == p2
# Out:
# True

# %%
dataclasses.asdict(p)
# Out:
# {'x': 10, 'y': 20}
