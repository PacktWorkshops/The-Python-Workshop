# %%
import random
import time

# %%
start = time.time()
l = [random.randint(1, 999) for _ in range(10 * 6)]
end = time.time()
print(end - start)
# Out:
# 0.0

# %%
start = time.time_ns()
l = [random.randint(1, 999) for _ in range(10 * 6)]
end = time.time_ns()
print(end - start)
# Out:
# 998100
