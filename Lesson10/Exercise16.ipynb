# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

housing_df = pd.read_csv('HousingData.csv')
sns.set()
# %matplotlib inline

x = housing_df['RM']

# %%
plt.boxplot(x)
plt.show()

# %%
plt.violinplot(x)
plt.show()
